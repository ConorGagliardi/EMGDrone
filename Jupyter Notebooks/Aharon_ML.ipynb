# %%
import numpy as np
import pandas as pd
import scipy as sp
import scipy.signal
import matplotlib.pyplot as plt
import os
import sklearn
import mne
import tensorflow as tf

# %%
# Import data
directory = 'Data'
participants = ['Aharon', 'Conor', 'John']
directory_2 = 'One\Thalmic Labs MyoMyo'
frames = []
for participant in participants:
    for count, filename in enumerate(os.listdir(os.path.join(directory, participant, directory_2))):
        df = pd.read_csv(os.path.join(directory, participant, directory_2, filename))
        df.drop(['Timestamp','Device ID','Warm?','Sync','Arm','Timestamp.1','Pose','Locked','RSSI','Device_Time'], axis=1, inplace=True)
        
        df.drop(['Orientation_W'], axis=1, inplace=True)
        
        df['Participant'] = [participant] * df.shape[0]
        filename = filename.split('_')
        if len(filename) == 3:
            df['Class'] = [filename[0]] * df.shape[0]
            df['Trial'] = [filename[1]] * df.shape[0]
        else:
            df['Class'] = [filename[0] + ' ' + filename[1]] * df.shape[0]
            df['Trial'] = [filename[2]] * df.shape[0]
        frames.append(df)
# data = pd.concat(frames)

# %%
# Preprocess EMU
def filteremg(emg, notch=60, quality=60, sfreq=200, high_band=20, low_band=95):
    """
    emg: EMG data
    high: high-pass cut off frequency
    low: low-pass cut off frequency
    sfreq: sampling frequency
    """
    # Zero mean emg signal
    emg = emg - emg.mean()
    
    # normalise cut-off frequencies to sampling frequency
    high_band = high_band/(sfreq/2)
    low_band = low_band/(sfreq/2)
    
    
    # create bandpass filter for EMG
    b1, a1 = sp.signal.butter(4, [high_band,low_band], btype='bandpass', analog=True)
    
    # process EMG signal: filter EMG
    emg_filtered = sp.signal.filtfilt(b1, a1, emg)    
    
    # process EMG signal: rectify
    emg_rectified = abs(emg_filtered)
    
    # create lowpass filter and apply to rectified signal to get EMG envelope
    notch = notch/(sfreq)
    b2, a2 = sp.signal.iirnotch(notch, quality, fs=sfreq)
    emg_envelope = sp.signal.lfilter(b2, a2, emg_rectified)
    
    return emg_envelope

emg_keys = ['EMG_' + str(i) for i in range(1, 9)]
imu_keys = ['Orientation_X','Orientation_Y','Orientation_Z','Gyro_X','Gyro_Y','Gyro_Z','Acc_X', 'Acc_Y', 'Acc_Z']

for frame in frames:
    frame[emg_keys] = frame[emg_keys].apply(filteremg, raw=True)

    # for channel in range(1,9):
    #     f, Pxx_den = sp.signal.periodogram(frame['EMG_' + str(channel)], 200)
    #     plt.figure()
    #     plt.semilogy(f, Pxx_den)
    #     plt.title('EMG_' + str(channel) + ' PSD')
    #     plt.ylim([1e-7, 1e2])
    #     plt.xlabel('frequency [Hz]')
    #     plt.ylabel('PSD [V**2/Hz]')
    #     plt.show()
    #         plt.savefig(directory + 'EMG_' + str(channel) + ' PSD.png')
    #     display('EMG_' + str(channel) + ' max power:', max(Pxx_den))
    for col in emg_keys:
        frame[col] = frame[col].rolling(20).mean() # how many samples should I make my window?
#     for channel in range(1,9):
#         plt.figure()
#         ax = frame['EMG_' + str(channel)].plot()
#         plt.title('EMG_' + str(channel) + ' Filtered')
#         plt.ylabel('mVolts')
#         plt.xlabel('Time')
    #         plt.savefig(directory + 'EMG_' + str(channel) + ' Filtered.png')

# %%
# Preprocess IMU
for frame in frames:
    for col in imu_keys:
        frame[col] = frame[col].rolling(5).mean()  # how many samples should I make my window?
    # for channel in ['X', 'Y', 'Z']:
    #     plt.figure()
    #     frame['Acc_' + channel].plot()
    #     plt.title('Acc_' + str(channel))
    #     plt.ylabel('g')
    #     plt.xlabel('Time')

# %%
# Feature Extraction
# Root Mean Square
def get_RMS(signal):
    ans = np.sqrt(np.average(np.square(signal)))
    return ans

# # Integral
# def get_IL(signal):
#     ans = np.sum(np.absolute(signal))
#     return ans

# Waveform Length
def get_WL(signal):
    ans = np.log(sum([np.absolute(signal[i+1] - signal[i]) for i in range(len(signal)-1)]))
    return ans

# Mean Absolute Value
def get_MAV(signal):
    ans = np.average(np.absolute(signal))
    return ans

# Slope Sign Change
# def get_SSC(signal):
#     ans = 0
#     for i in range(len(signal)-1):
#         if 
#     return ans

# Variance
def get_VAR(signal):
    ans = np.var(signal)
    return ans

# Max Power
def get_MAXP(signal):
    f, Pxx_den = sp.signal.periodogram(signal, 200)
    ans = max(Pxx_den)
    return ans

# Range of Values
def get_dRange(signal):
    ans = max(signal) - min(signal)
    return ans

# Max Value
def get_MAX(signal):
    ans = max(signal)
    return ans

def extract_features(dataframe, emg_channels, or_channels, gyro_channels, acc_channels):
    feat_dict = {}
    for chan in emg_channels:
        feat_dict[chan + '_RMS'] = get_RMS(dataframe[chan].dropna().reset_index(drop=True))
#         feat_dict[chan + '_IL'] = get_IL(dataframe[chan].dropna().reset_index(drop=True))
        feat_dict[chan + '_WL'] = get_WL(dataframe[chan].dropna().reset_index(drop=True))
        feat_dict[chan + '_MAV'] = get_MAV(dataframe[chan].dropna().reset_index(drop=True))
        feat_dict[chan + '_VAR'] = get_VAR(dataframe[chan].dropna().reset_index(drop=True))
        feat_dict[chan + '_MAXP'] = get_MAXP(dataframe[chan].dropna().reset_index(drop=True))
        feat_dict[chan + '_MAX'] = get_MAX(dataframe[chan].dropna().reset_index(drop=True))
    for chan in or_channels:
        feat_dict[chan + '_dOrient'] = get_dRange(dataframe[chan].dropna().reset_index(drop=True))
    for chan in gyro_channels:
        feat_dict[chan + '_dGyro'] = get_dRange(dataframe[chan].dropna().reset_index(drop=True))
    for chan in or_channels + gyro_channels + acc_channels:
        feat_dict[chan + '_VAR'] = get_VAR(dataframe[chan].dropna().reset_index(drop=True))
    for chan in acc_channels:
        feat_dict[chan + '_MAX'] = get_MAX(dataframe[chan].dropna().reset_index(drop=True))
    return feat_dict

or_keys = imu_keys[:4]
gyro_keys = imu_keys[4:7]
acc_keys = imu_keys[7:]

feature_df = pd.DataFrame()
for frame in frames:
    feats = extract_features(frame, emg_keys, or_keys, gyro_keys, acc_keys)
    feats['Participant'] = frame['Participant']
    feats['Class'] = frame['Class']
    feats['Trial'] = frame['Trial']
    feature_df = pd.concat([feature_df, pd.DataFrame(feats, index=[0])], ignore_index=True)

# %%
# Setup Data for ML
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout, Activation
from keras.utils import np_utils
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

train_cols = list(feature_df)[:-3]

classes = np.unique(feature_df['Class'])
class_to_int = {c:i for i, c in enumerate(classes)}
y_cols = ['y_' + str(i) for i in range(len(classes))]
one_hot_matrix = np.zeros((len(feature_df), len(classes)))
for i, c in enumerate(feature_df['Class']):
    index = class_to_int[c]
    one_hot_matrix[i, index] = 1
y_df = pd.DataFrame(one_hot_matrix, columns=y_cols)
feature_df = pd.concat([feature_df,y_df], axis=1)

feature_train, feature_test = train_test_split(feature_df, train_size=0.8, test_size=0.2, shuffle=True)

x = feature_train.loc[:,train_cols]
min_max_scalar = MinMaxScaler()
x_train = min_max_scalar.fit_transform(x)
x_test = min_max_scalar.transform(feature_test.loc[:,train_cols])
y_train = feature_train.loc[:,y_cols].values
y_test = feature_test.loc[:,y_cols].values

# %%
# Machine Learning
# print(x_train.shape)
model = Sequential([
    Input(shape=(66,)),
    Dense(128, activation='relu'),
    Dropout(0.1),
    Dense(64, activation='relu'),
    Dropout(0.1),
    Dense(15, activation='softmax')
])

model.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy','mse'])

model.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 1s 2ms/step - loss: 2.6740 - accuracy: 0.0917 - mse: 0.0619
# Epoch 2/100
# 8/8 [==============================] - 0s 1ms/step - loss: 2.5608 - accuracy: 0.2417 - mse: 0.0607
# Epoch 3/100
# 8/8 [==============================] - 0s 1ms/step - loss: 2.4756 - accuracy: 0.2250 - mse: 0.0598
# Epoch 4/100
# 8/8 [==============================] - 0s 1ms/step - loss: 2.3572 - accuracy: 0.3042 - mse: 0.0581
# Epoch 5/100
# 8/8 [==============================] - 0s 1ms/step - loss: 2.2351 - accuracy: 0.3792 - mse: 0.0561
# Epoch 6/100
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0899 - accuracy: 0.4083 - mse: 0.0534
# Epoch 7/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9937 - accuracy: 0.4125 - mse: 0.0516
# Epoch 8/100
# 8/8 [==============================] - 0s 1ms/step - loss: 1.8579 - accuracy: 0.4708 - mse: 0.0491
# Epoch 9/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7248 - accuracy: 0.5917 - mse: 0.0466
# Epoch 10/100
# 8/8 [==============================] - 0s 1ms/step - loss: 1.6121 - accuracy: 0.5875 - mse: 0.0445
# Epoch 11/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5224 - accuracy: 0.6167 - mse: 0.0425
# Epoch 12/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3934 - accuracy: 0.6875 - mse: 0.0397
# Epoch 13/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2965 - accuracy: 0.7125 - mse: 0.0375
# Epoch 14/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2084 - accuracy: 0.7542 - mse: 0.0355
# Epoch 15/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1167 - accuracy: 0.7625 - mse: 0.0329
# Epoch 16/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0058 - accuracy: 0.8083 - mse: 0.0299
# Epoch 17/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9946 - accuracy: 0.7542 - mse: 0.0298
# Epoch 18/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9742 - accuracy: 0.7292 - mse: 0.0301
# Epoch 19/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8655 - accuracy: 0.8167 - mse: 0.0260
# Epoch 20/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8295 - accuracy: 0.7875 - mse: 0.0253
# Epoch 21/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7818 - accuracy: 0.7833 - mse: 0.0240
# Epoch 22/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7522 - accuracy: 0.8042 - mse: 0.0232
# Epoch 23/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6924 - accuracy: 0.8292 - mse: 0.0211
# Epoch 24/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6766 - accuracy: 0.8500 - mse: 0.0206
# Epoch 25/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6911 - accuracy: 0.8042 - mse: 0.0221
# Epoch 26/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6272 - accuracy: 0.8542 - mse: 0.0200
# Epoch 27/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5706 - accuracy: 0.8625 - mse: 0.0181
# Epoch 28/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5915 - accuracy: 0.8250 - mse: 0.0188
# Epoch 29/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5443 - accuracy: 0.8708 - mse: 0.0170
# Epoch 30/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5581 - accuracy: 0.8583 - mse: 0.0180
# Epoch 31/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5006 - accuracy: 0.8625 - mse: 0.0155
# Epoch 32/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4992 - accuracy: 0.8583 - mse: 0.0156
# Epoch 33/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5029 - accuracy: 0.8625 - mse: 0.0161
# Epoch 34/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4795 - accuracy: 0.8667 - mse: 0.0149
# Epoch 35/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4722 - accuracy: 0.8542 - mse: 0.0153
# Epoch 36/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4359 - accuracy: 0.8750 - mse: 0.0139
# Epoch 37/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3996 - accuracy: 0.9125 - mse: 0.0121
# Epoch 38/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4178 - accuracy: 0.8833 - mse: 0.0133
# Epoch 39/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3807 - accuracy: 0.9167 - mse: 0.0117
# Epoch 40/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3785 - accuracy: 0.9125 - mse: 0.0117
# Epoch 41/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3856 - accuracy: 0.8875 - mse: 0.0124
# Epoch 42/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3783 - accuracy: 0.9083 - mse: 0.0116
# Epoch 43/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3871 - accuracy: 0.9000 - mse: 0.0125
# Epoch 44/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3941 - accuracy: 0.8917 - mse: 0.0129
# Epoch 45/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3440 - accuracy: 0.9167 - mse: 0.0105
# Epoch 46/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3527 - accuracy: 0.9208 - mse: 0.0110
# Epoch 47/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3417 - accuracy: 0.9208 - mse: 0.0109
# Epoch 48/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3276 - accuracy: 0.9208 - mse: 0.0102
# Epoch 49/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3269 - accuracy: 0.9167 - mse: 0.0102
# Epoch 50/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3125 - accuracy: 0.9375 - mse: 0.0098
# Epoch 51/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2876 - accuracy: 0.9458 - mse: 0.0085
# Epoch 52/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2498 - accuracy: 0.9542 - mse: 0.0075
# Epoch 53/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2866 - accuracy: 0.9125 - mse: 0.0093
# Epoch 54/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2586 - accuracy: 0.9417 - mse: 0.0080
# Epoch 55/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2482 - accuracy: 0.9542 - mse: 0.0073
# Epoch 56/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2578 - accuracy: 0.9375 - mse: 0.0080
# Epoch 57/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2620 - accuracy: 0.9417 - mse: 0.0082
# Epoch 58/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2284 - accuracy: 0.9708 - mse: 0.0067
# Epoch 59/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2432 - accuracy: 0.9458 - mse: 0.0078
# Epoch 60/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2403 - accuracy: 0.9292 - mse: 0.0074
# Epoch 61/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2382 - accuracy: 0.9500 - mse: 0.0075
# Epoch 62/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2145 - accuracy: 0.9583 - mse: 0.0063
# Epoch 63/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2103 - accuracy: 0.9500 - mse: 0.0064
# Epoch 64/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2264 - accuracy: 0.9458 - mse: 0.0069
# Epoch 65/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2194 - accuracy: 0.9500 - mse: 0.0068
# Epoch 66/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2343 - accuracy: 0.9542 - mse: 0.0072
# Epoch 67/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1991 - accuracy: 0.9542 - mse: 0.0059
# Epoch 68/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2324 - accuracy: 0.9417 - mse: 0.0073
# Epoch 69/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2186 - accuracy: 0.9625 - mse: 0.0063
# Epoch 70/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2010 - accuracy: 0.9417 - mse: 0.0061
# Epoch 71/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1841 - accuracy: 0.9667 - mse: 0.0054
# Epoch 72/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1875 - accuracy: 0.9583 - mse: 0.0059
# Epoch 73/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2313 - accuracy: 0.9292 - mse: 0.0074
# Epoch 74/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1776 - accuracy: 0.9792 - mse: 0.0053
# Epoch 75/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1725 - accuracy: 0.9625 - mse: 0.0048
# Epoch 76/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1885 - accuracy: 0.9625 - mse: 0.0057
# Epoch 77/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1572 - accuracy: 0.9833 - mse: 0.0042
# Epoch 78/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1671 - accuracy: 0.9583 - mse: 0.0047
# Epoch 79/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1528 - accuracy: 0.9750 - mse: 0.0044
# Epoch 80/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1640 - accuracy: 0.9458 - mse: 0.0049
# Epoch 81/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1342 - accuracy: 0.9833 - mse: 0.0035
# Epoch 82/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1750 - accuracy: 0.9542 - mse: 0.0054
# Epoch 83/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1792 - accuracy: 0.9625 - mse: 0.0054
# Epoch 84/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1670 - accuracy: 0.9667 - mse: 0.0049
# Epoch 85/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1626 - accuracy: 0.9667 - mse: 0.0048
# Epoch 86/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1490 - accuracy: 0.9708 - mse: 0.0043
# Epoch 87/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1523 - accuracy: 0.9625 - mse: 0.0046
# Epoch 88/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1288 - accuracy: 0.9917 - mse: 0.0033
# Epoch 89/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1319 - accuracy: 0.9750 - mse: 0.0037
# Epoch 90/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1520 - accuracy: 0.9625 - mse: 0.0046
# Epoch 91/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1367 - accuracy: 0.9708 - mse: 0.0042
# Epoch 92/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1169 - accuracy: 0.9792 - mse: 0.0033
# Epoch 93/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1228 - accuracy: 0.9792 - mse: 0.0032
# Epoch 94/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1335 - accuracy: 0.9792 - mse: 0.0038
# Epoch 95/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1410 - accuracy: 0.9583 - mse: 0.0044
# Epoch 96/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1234 - accuracy: 0.9708 - mse: 0.0036
# Epoch 97/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1174 - accuracy: 0.9792 - mse: 0.0033
# Epoch 98/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1248 - accuracy: 0.9750 - mse: 0.0034
# Epoch 99/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1335 - accuracy: 0.9625 - mse: 0.0042
# Epoch 100/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1328 - accuracy: 0.9708 - mse: 0.0039

# %%
model.evaluate(x_test, y_test)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4216 - accuracy: 0.8833 - mse: 0.0143
# [0.42161476612091064, 0.8833333253860474, 0.014269727282226086]

# %%
predicted = model.predict(x_test)
predicted = np.argmax(predicted, axis=1)+1
true = np.argmax(y_test, axis=1)+1
display(pd.DataFrame(classification_report(true, predicted, output_dict=True)).transpose())

cm = confusion_matrix(true, predicted)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %%
model.save("Aharon_Original_NN_Model")
